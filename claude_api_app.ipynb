# %%
print("Hello how are you?")
# Out:
# Hello how are you?

# %%
# install anthropic environment package

# %pip install anthropic python-dotenv

# %%
#load environment
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# create API client



client = Anthropic()
model = "claude-sonnet-4-0"

# %%
client = Anthropic()
model = "claude-sonnet-4-6"

message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role" : "user",
            "content" : "Why is Sachin Tendulkar considered God of Cricket?"
        }
    ]
)

# %%
message.content[0].text
# Out:
# '# Sachin Tendulkar - "God of Cricket"\n\nSachin Tendulkar earned this title through a combination of extraordinary achievements and qualities:\n\n## Record-Breaking Statistics\n- **100 international centuries** - the only player to achieve this\n- **Most runs in Test cricket** (15,921) and ODIs (18,426)\n- Played **664 international matches** over 24 years\n- Scored first **double century in ODI history**\n\n## Longevity & Consistency\n- Debuted at **age 16** (1989) and retired at **40** (2013)\n- Maintained elite performance across **different eras** of cricket\n- Consistent against all bowling attacks worldwide\n\n## Technical Excellence\n- Regarded as having **near-perfect batting technique**\n- Masterful against both pace and spin bowling\n- Performed on all types of pitches globally\n\n## Cultural & Emotional Impact\n- Cricket is **deeply religious** in India - his status reflected that passion\n- Carried enormous **national expectations** with grace\n- Inspired generations of cricketers\n\n## Recognition\n- Won **Bharat Ratna** (India\'s highest civilian honor)\n- Respected universally by players, coaches and fans\n- Even rivals acknowledged his greatness\n\n## Beyond Statistics\n- Known for **humility, sportsmanship** and dedication\n- Represented hope and pride for over a billion people\n\nHis combination of **records, longevity, technique and cultural impact** made the title fitting.'
